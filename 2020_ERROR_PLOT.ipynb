# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import math
import random

# %%
for i in range(100):
    with open("fftdataok.csv", "rU") as file:
        x = []
        data = csv.reader(file)
        #데이터 받아오기
        for row in data:
            x.append(float(row[i+1]))
        x.pop(0)
        
        plt.plot(range(len(x)), x)
        plt.ylim(0.4, 1)
        plt.xlim(0, 484)

        plt.xlabel('Frequency(Index)') 
        plt.ylabel('Magnitude') 
        #plt.title('Histogram of IQ') 
        plt.show()

# %%
for i in range(100):
    with open("data100setz.csv", "rU") as file:
        x = []
        data = csv.reader(file)
        #데이터 받아오기
        cnt = 0
        for row in data:
            x.append(float(row[i+1]))
        x.pop(0)
        
        plt.plot(range(len(x)), x)
        plt.ylim(0, 1)
        plt.xlim(0, 484)

        plt.xlabel('Frequency(Index)') 
        plt.ylabel('Magnitude') 
        #plt.title('Histogram of IQ') 
        plt.show()

# %%
for i in range(100):
    with open("error_1.csv", "rU") as file:
        x = []
        data = csv.reader(file)
        #데이터 받아오기
        for row in data:
            x.append(float(row[i+1]))
        x.pop(0)
        
        plt.plot(range(len(x)), x)
        plt.ylim(0.4, 1)

plt.show()

# %%
for i in range(100):
    with open("error_2.csv", "rU") as file:
        x = []
        data = csv.reader(file)
        #데이터 받아오기
        for row in data:
            x.append(float(row[i+1]))
        x.pop(0)
        
        plt.plot(range(len(x)), x)
        plt.ylim(0.4, 1)

plt.show()

# %%
for i in range(100):
    with open("error_3.csv", "rU") as file:
        x = []
        data = csv.reader(file)
        #데이터 받아오기
        for row in data:
            x.append(float(row[i+1]))
        x.pop(0)
        
        plt.plot(range(len(x)), x)
        plt.ylim(0.4, 1)

        plt.show()

# %%
for i in range(23):
    with open("error_3.csv", "rU") as file:
        x = []
        data = csv.reader(file)
        #데이터 받아오기
        for row in data:
            x.append(float(row[i+1]))
        x.pop(0)
        
        plt.plot(range(len(x)), x)
        plt.ylim(0.4, 1)
        plt.xlim(0, 484)

        plt.xlabel('Frequency(Index)') 
        plt.ylabel('Magnitude') 
        #plt.title('Histogram of IQ') 
        plt.show()
