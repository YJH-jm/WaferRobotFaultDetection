# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import math
from sklearn.cluster import KMeans
import tensorflow as tf
#from sklearn.datasets import make_blobs
#import pandas

# %%
def dataShape(centerList, choice, X, Y):
    center = []
    for i in range(len(centerList)): #센터 점 리스트구조로 변형
        center.append([centerList[:,0][i], centerList[:,1][i]])
        
    #center점의
    for i in range(len(center)-1):
        for j in range(i+1, len(center)):
            if center[i][0] > center[j][0]:
                tmp = center[i]
                center[i] = center[j]
                center[j] = tmp
            
    train = []
    for i in range(len(center)):
        train.append(center[i][0])
        train.append(center[i][1])
    
    if len(train) < 8:
        for i in range(8 - len(train)):
            train.append(0)
            
    X.append(train)
    if choice == 0: 
        Y.append([1, 0, 0, 0])
    elif choice == 1:
        Y.append([0, 1, 0, 0])
    elif choice == 2:
        Y.append([0, 0, 1, 0])
    elif choice == 3:
        Y.append([0, 0, 0, 1])

# %%
def dataTrainingKmeans(choice, trainX, trainY):
    if choice == 0:
        for i in range(100):
            with open("fftdataok.csv", "rU") as file:
                data = csv.reader(file)
                #데이터 받아오기
                x = []
                for row in data:
                    x.append(float(row[i+1]))
                x.pop(0)
                x = x[:484]

                result = []
                #의미있는 데이터 모으기
                for j in range(len(x)):
                    if x[j] >= 0.4:
                        result.append([j, x[j]])

                if len(result) == 1: 
                    model = KMeans(n_clusters = 1)
                elif len(result) == 2: 
                    model = KMeans(n_clusters = 2)
                elif len(result) == 3: 
                    model = KMeans(n_clusters=3)
                else:
                    model = KMeans(n_clusters=4)
                model.fit(result)

                centers = model.cluster_centers_
                
               
                dataShape(centers, choice, trainX, trainY)
        
            '''
            plt.scatter(x=centers[:,0], y=centers[:,1], marker='D', c='r')
            plt.xlim(0, 484)
            plt.ylim(0.4, 1)
            plt.show()
            '''
    elif choice == 1:
        for i in range(100):
            with open("error_1.csv", "rU") as file:
                data = csv.reader(file)
                #데이터 받아오기
                x = []
                for row in data:
                    x.append(float(row[i+1]))
                x.pop(0)
                x = x[:484]

                result = []
                #의미있는 데이터 모으기
                for j in range(len(x)):
                    if x[j] >= 0.4:
                        result.append([j, x[j]])

                model = KMeans(n_clusters=4)
                model.fit(result)

                centers = model.cluster_centers_
                dataShape(centers, choice, trainX, trainY)
                
    elif choice == 2:
        for i in range(100):
            with open("error_2.csv", "rU") as file:
                data = csv.reader(file)
                #데이터 받아오기
                x = []
                for row in data:
                    x.append(float(row[i+1]))
                x.pop(0)
                #print(x)
                x = x[:484]

                result = []
                #의미있는 데이터 모으기
                for j in range(len(x)):
                    if x[j] >= 0.4:
                        result.append([j, x[j]])


                model = KMeans(n_clusters=4)
                model.fit(result)

                centers = model.cluster_centers_
                dataShape(centers, choice, trainX, trainY)
                
    elif choice == 3:
        for i in range(100):
            with open("error_3.csv", "rU") as file:
                data = csv.reader(file)
                #데이터 받아오기
                x = []
                for row in data:
                    x.append(float(row[i+1]))
                x.pop(0)
                x = x[:484]

                result = []
                #의미있는 데이터 모으기
                for j in range(len(x)):
                    if x[j] >= 0.4:
                        result.append([j, x[j]])

                model = KMeans(n_clusters=4)

                model.fit(result)

                centers = model.cluster_centers_
                dataShape(centers, choice, trainX, trainY)

# %%
def dataTestKmeans(choice, testX, testY):
    if choice == 0:
        for i in range(100):
            with open("testNormal.csv", "rU") as file:
                data = csv.reader(file)
                #데이터 받아오기
                x = []
                for row in data:
                    x.append(float(row[i+1]))
                x.pop(0)
                x = x[:484]

                result = []
                #의미있는 데이터 모으기
                for j in range(len(x)):
                    if x[j] >= 0.4:
                        result.append([j, x[j]])

                if len(result) == 1: 
                    model = KMeans(n_clusters = 1)
                elif len(result) == 2: 
                    model = KMeans(n_clusters = 2)
                elif len(result) == 3: 
                    model = KMeans(n_clusters=3)
                else:
                    model = KMeans(n_clusters=4)
                model.fit(result)

                centers = model.cluster_centers_
                
                
                dataShape(centers, choice, testX, testY)
        
            '''
            plt.scatter(x=centers[:,0], y=centers[:,1], marker='D', c='r')
            plt.xlim(0, 484)
            plt.ylim(0.4, 1)
            plt.show()
            '''
    elif choice == 1:
        for i in range(100):
            with open("testError1.csv", "rU") as file:
                data = csv.reader(file)
                #데이터 받아오기
                x = []
                for row in data:
                    x.append(float(row[i+1]))
                x.pop(0)
                x = x[:484]

                result = []
                #의미있는 데이터 모으기
                for j in range(len(x)):
                    if x[j] >= 0.4:
                        result.append([j, x[j]])

                model = KMeans(n_clusters=4)
                model.fit(result)

                centers = model.cluster_centers_
                dataShape(centers, choice, testX, testY)
                
    elif choice == 2:
        for i in range(100):
            with open("testError2.csv", "rU") as file:
                data = csv.reader(file)
                #데이터 받아오기
                x = []
                for row in data:
                    x.append(float(row[i+1]))
                x.pop(0)
                #print(x)
                x = x[:484]

                result = []
                #의미있는 데이터 모으기
                for j in range(len(x)):
                    if x[j] >= 0.4:
                        result.append([j, x[j]])


                model = KMeans(n_clusters=4)
                model.fit(result)

                centers = model.cluster_centers_
                dataShape(centers, choice, testX, testY)
                
    elif choice == 3:
        for i in range(100):
            with open("testError3.csv", "rU") as file:
                data = csv.reader(file)
                #데이터 받아오기
                x = []
                for row in data:
                    x.append(float(row[i+1]))
                x.pop(0)
                x = x[:484]

                result = []
                #의미있는 데이터 모으기
                for j in range(len(x)):
                    if x[j] >= 0.4:
                        result.append([j, x[j]])

                model = KMeans(n_clusters=4)

                model.fit(result)

                centers = model.cluster_centers_
                dataShape(centers, choice, testX, testY)

# %%
def dataTestKmeans2(choice, testX, testY):
    if choice == 0:
        for i in range(100):
            with open("testNormal.csv", "rU") as file:
                data = csv.reader(file)
                #데이터 받아오기
                x = []
                for row in data:
                    x.append(float(row[i+1]))
                x.pop(0)
                x = x[:484]

                result = []
                #의미있는 데이터 모으기
                for j in range(len(x)):
                    if x[j] >= 0.4:
                        result.append([j, x[j]])

                if len(result) == 1: 
                    model = KMeans(n_clusters = 1)
                elif len(result) == 2: 
                    model = KMeans(n_clusters = 2)
                elif len(result) == 3: 
                    model = KMeans(n_clusters=3)
                else:
                    model = KMeans(n_clusters=4)
                model.fit(result)

                centers = model.cluster_centers_
                
                
                dataShape(centers, choice, testX, testY)
        
            '''
            plt.scatter(x=centers[:,0], y=centers[:,1], marker='D', c='r')
            plt.xlim(0, 484)
            plt.ylim(0.4, 1)
            plt.show()
            '''
    elif choice == 1:
        for i in range(100):
            with open("testError1_2.csv", "rU") as file:
                data = csv.reader(file)
                #데이터 받아오기
                x = []
                for row in data:
                    x.append(float(row[i+1]))
                x.pop(0)
                x = x[:484]

                result = []
                #의미있는 데이터 모으기
                for j in range(len(x)):
                    if x[j] >= 0.4:
                        result.append([j, x[j]])

                model = KMeans(n_clusters=4)
                model.fit(result)

                centers = model.cluster_centers_
                dataShape(centers, choice, testX, testY)
                
    elif choice == 2:
        for i in range(100):
            with open("testError2_2.csv", "rU") as file:
                data = csv.reader(file)
                #데이터 받아오기
                x = []
                for row in data:
                    x.append(float(row[i+1]))
                x.pop(0)
                #print(x)
                x = x[:484]

                result = []
                #의미있는 데이터 모으기
                for j in range(len(x)):
                    if x[j] >= 0.4:
                        result.append([j, x[j]])


                model = KMeans(n_clusters=4)
                model.fit(result)

                centers = model.cluster_centers_
                dataShape(centers, choice, testX, testY)
                
    elif choice == 3:
        for i in range(100):
            with open("testError3_2.csv", "rU") as file:
                data = csv.reader(file)
                #데이터 받아오기
                x = []
                for row in data:
                    x.append(float(row[i+1]))
                x.pop(0)
                x = x[:484]

                result = []
                #의미있는 데이터 모으기
                for j in range(len(x)):
                    if x[j] >= 0.4:
                        result.append([j, x[j]])

                model = KMeans(n_clusters=4)

                model.fit(result)

                centers = model.cluster_centers_
                dataShape(centers, choice, testX, testY)

# %%
def getTrainingData():
    train_x = []
    train_y = []
    dataTrainingKmeans(0, train_x, train_y)
    dataTrainingKmeans(1, train_x, train_y)
    dataTrainingKmeans(2, train_x, train_y)
    dataTrainingKmeans(3, train_x, train_y)
    
    return train_x, train_y

# %%
def getTestData(num):
    test_x = []
    test_y = []
    if num == 1:
        dataTestKmeans(0, test_x, test_y)
        dataTestKmeans(1, test_x, test_y)
        dataTestKmeans(2, test_x, test_y)
        dataTestKmeans(3, test_x, test_y)
    elif num == 2:
        dataTestKmeans2(0, test_x, test_y)
        dataTestKmeans2(1, test_x, test_y)
        dataTestKmeans2(2, test_x, test_y)
        dataTestKmeans2(3, test_x, test_y)
    return test_x, test_y

# %%
def modeling():
    trainDataX = []
    trainDataY = []
    trainDataX, trainDataY = getTrainingData()
    """
    print("----------------------------")
    print("Train : ", trainDataX)
    print("----------------------------")
    print("TrainDataY : ", trainDataY)
    """
    trainDataX = np.array(trainDataX)
    trainDataY = np.array(trainDataY)
    
    testDataX = []
    testDataY = []
    testDataX, testDataY = getTestData(1)
    testDataX2 = []
    testDataY2 = []
    testDataX2, testDataY2 = getTestData(2)
    """
    print("----------------------------")
    print("testDataX : ", testDataX)
    print("----------------------------")
    print("testDataY : ", testDataY)
    """
    testDataX = np.array(testDataX)
    testDataY = np.array(testDataY)
    
    testDataX2 = np.array(testDataX2)
    testDataY2 = np.array(testDataY2)
    
    X = tf.placeholder(tf.float32, shape=[None, 8])
    Y = tf.placeholder(tf.float32, shape=[None, 4])
    
    #W1 = tf.Variable(tf.random_normal([8, 8], -1., 1.))
    W1 = tf.get_variable("W1", shape=[8, 8], initializer=tf.contrib.layers.xavier_initializer())
    b1 = tf.Variable(tf.random_normal([8]))
    L1 = tf.nn.relu(tf.add(tf.matmul(X, W1), b1))
    
    #W2 = tf.Variable(tf.random_normal([8, 10]))
    W2 = tf.get_variable("W2", shape=[8, 10], initializer=tf.contrib.layers.xavier_initializer())
    b2 = tf.Variable(tf.random_normal([10]))
    L2 = tf.nn.relu(tf.add(tf.matmul(L1, W2), b2))
    
    #W3 = tf.Variable(tf.random_normal([10, 12]))
    W3 = tf.get_variable("W3", shape=[10, 12], initializer=tf.contrib.layers.xavier_initializer())
    b3 = tf.Variable(tf.random_normal([12]))
    L3 = tf.nn.relu(tf.add(tf.matmul(L2, W3), b3))
    
    #W4 = tf.Variable(tf.random_normal([12, 10]))
    W4 = tf.get_variable("W4", shape=[12, 10], initializer=tf.contrib.layers.xavier_initializer())
    b4 = tf.Variable(tf.random_normal([10]))
    L4 = tf.nn.relu(tf.add(tf.matmul(L3, W4), b4))
    
    #W5 = tf.Variable(tf.random_normal([10, 8]))
    W5 = tf.get_variable("W5", shape=[10, 8], initializer=tf.contrib.layers.xavier_initializer())
    b5 = tf.Variable(tf.random_normal([8]))
    L5 = tf.nn.relu(tf.add(tf.matmul(L4, W5), b5))
 
    #W6 = tf.Variable(tf.random_normal([8, 4]))
    W6 = tf.get_variable("W6", shape=[8, 4], initializer=tf.contrib.layers.xavier_initializer())
    b6 = tf.Variable(tf.random_normal([4]))
    model = tf.add(tf.matmul(L5, W6), b6)
  
    
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=Y, logits=model))
 
    optimizer = tf.train.AdamOptimizer(learning_rate=0.01)
    train_op = optimizer.minimize(cost)
 

    init = tf.global_variables_initializer()
    sess = tf.Session()
    sess.run(init)
 
    for step in range(1200):
        sess.run(train_op, feed_dict={X: trainDataX, Y: trainDataY})
        """
        if (step + 1) % 10 == 0:
            print(step + 1, sess.run(cost, feed_dict={X: trainDataX, Y: trainDataY}))
        """
 

    prediction = tf.argmax(model, 1)
    target = tf.argmax(Y, 1)
    print('예측값1:', sess.run(prediction, feed_dict={X: testDataX}))
    print('실제값1:', sess.run(target, feed_dict={Y: testDataY}))
    
    is_correct = tf.equal(prediction, target)
    accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))
    print('정확도1: %.2f' % sess.run(accuracy * 100, feed_dict={X: testDataX, Y: testDataY}))
    #
    print('예측값1:', sess.run(prediction, feed_dict={X: testDataX2}))
    print('실제값1:', sess.run(target, feed_dict={Y: testDataY2}))
    
    is_correct = tf.equal(prediction, target)
    accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))
    print('정확도1: %.2f' % sess.run(accuracy * 100, feed_dict={X: testDataX2, Y: testDataY2}))
    sess.close()
    '''
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
 
        for step in range(100):
            sess.run(train_op, feed_dict={X: trainDataX, Y: trainDataY})
 
            if (step + 1) % 10 == 0:
                print(step + 1, sess.run(cost, feed_dict={X: trainDataX, Y: trainDataX}))
 
        prediction = tf.argmax(model, axis=1)
        target = tf.argmax(Y, axis=1)
        print('예측값:', sess.run(prediction, feed_dict={X: testDataX}))
        print('실제값:', sess.run(target, feed_dict={Y: testDataY}))
 
        is_correct = tf.equal(prediction, target)
        accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))
        print('정확도: %.2f' % sess.run(accuracy * 100, feed_dict={X: testDataX, Y: testDataY}))
 '''
